# %%
import pandas as pd
df = pd.read_excel(r'/content/Customer Call List.xlsx')
df.head()
# Out:
#    CustomerID First_Name Last_Name  Phone_Number  \
# 0        1001      Frodo   Baggins  123-545-5421
# 1        1002       Abed     Nadir  123/643/9775
# 2        1003     Walter    /White    7066950392
# 3        1004     Dwight   Schrute  123-543-2345
# 4        1005        Jon      Snow  876|678|3469
#
#                                  Address Paying Customer Do_Not_Contact  \
# 0                  123 Shire Lane, Shire             Yes             No
# 1                    93 West Main Street              No            Yes
# 2                     298 Drugs Driveway               N            NaN
# 3  980 Paper Avenue, Pennsylvania, 18503             Yes              Y
# 4                       123 Dragons Road               Y             No
#
#    Not_Useful_Column
# 0               True
# 1              False
# 2               True
# 3               True
# 4               True

# %%
df =df.drop_duplicates()

# %% [markdown]
# ### **We are removing any kind of . or / or  _ from lastname**

# %%
df["Last_Name"] = df["Last_Name"].str.strip('123./_')
# Out:
# <ipython-input-3-a19342ce09b2>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["Last_Name"] = df["Last_Name"].str.strip('123./_')

# %%
df["Phone_Number"]= df["Phone_Number"].apply(lambda x: str(x))
# Out:
# <ipython-input-4-a98c3efdb9b7>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["Phone_Number"]= df["Phone_Number"].apply(lambda x: str(x))

# %%
df["Phone_Number"] = df["Phone_Number"].str.replace('nan','')
df["Phone_Number"] = df["Phone_Number"].str.replace('Na--','')
df["Phone_Number"] = df["Phone_Number"].str.replace('Na--','')
df["Phone_Number"] = df["Phone_Number"].str.replace('N/a','')
# Out:
# <ipython-input-5-70d3767a9459>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["Phone_Number"] = df["Phone_Number"].str.replace('nan','')
# <ipython-input-5-70d3767a9459>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["Phone_Number"] = df["Phone_Number"].str.replace('Na--','')
# <ipython-input-5-70d3767a9459>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...

# %%
df
# Out:
#     CustomerID First_Name   Last_Name  Phone_Number  \
# 0         1001      Frodo     Baggins  123-545-5421
# 1         1002       Abed       Nadir  123/643/9775
# 2         1003     Walter       White    7066950392
# 3         1004     Dwight     Schrute  123-543-2345
# 4         1005        Jon        Snow  876|678|3469
# 5         1006        Ron     Swanson  304-762-2467
# 6         1007       Jeff      Winger
# 7         1008   Sherlock      Holmes  876|678|3469
# 8         1009    Gandalf         NaN
# 9         1010      Peter      Parker  123-545-5421
# 10        1011    Samwise      Gamgee
# 11        1012      Harry      Potter    7066950392
# 12        1013        Don      Draper  123-543-2345
# 13        1014     Leslie       Knope  876|678|3469
# 14        1015       Toby  Flenderson  304-762-2467
# 15        1016        Ron     Weasley  123-545-5421
# 16        1017   Michael        Scott  123/643/9775
# 17        1018      Clark        Kent    7066950392
# ...

# %%
df[['Street', 'Rest']] = df['Address'].str.split(',', n=1, expand=True)
df[['State', 'Zip_code']] = df['Rest'].str.split(',', n=1, expand=True)
df = df.drop(columns=['Rest','Address'])

# %%
df
# Out:
#     CustomerID First_Name   Last_Name  Phone_Number Paying Customer  \
# 0         1001      Frodo     Baggins  123-545-5421             Yes
# 1         1002       Abed       Nadir  123/643/9775              No
# 2         1003     Walter       White    7066950392               N
# 3         1004     Dwight     Schrute  123-543-2345             Yes
# 4         1005        Jon        Snow  876|678|3469               Y
# 5         1006        Ron     Swanson  304-762-2467             Yes
# 6         1007       Jeff      Winger                            No
# 7         1008   Sherlock      Holmes  876|678|3469               N
# 8         1009    Gandalf         NaN                           Yes
# 9         1010      Peter      Parker  123-545-5421             Yes
# 10        1011    Samwise      Gamgee                           Yes
# 11        1012      Harry      Potter    7066950392               Y
# 12        1013        Don      Draper  123-543-2345             Yes
# ...

# %%
df["Paying Customer"] = df["Paying Customer"].str.replace('Yes','Y')
df["Paying Customer"] = df["Paying Customer"].str.replace('No','N')

# %%
df
# Out:
#     CustomerID First_Name   Last_Name  Phone_Number Paying Customer  \
# 0         1001      Frodo     Baggins  123-545-5421               Y
# 1         1002       Abed       Nadir  123/643/9775               N
# 2         1003     Walter       White    7066950392               N
# 3         1004     Dwight     Schrute  123-543-2345               Y
# 4         1005        Jon        Snow  876|678|3469               Y
# 5         1006        Ron     Swanson  304-762-2467               Y
# 6         1007       Jeff      Winger                             N
# 7         1008   Sherlock      Holmes  876|678|3469               N
# 8         1009    Gandalf         NaN                             Y
# 9         1010      Peter      Parker  123-545-5421               Y
# 10        1011    Samwise      Gamgee                             Y
# 11        1012      Harry      Potter    7066950392               Y
# 12        1013        Don      Draper  123-543-2345               Y
# ...

# %%
df["Do_Not_Contact"] = df["Do_Not_Contact"].str.replace('Yes','Y')
df["Do_Not_Contact"] = df["Do_Not_Contact"].str.replace('No','N')
df.replace('nan--','')
df.replace('NaN','')
df.replace('N/a','')
df.replace('Na--','')
# Out:
#     CustomerID First_Name   Last_Name  Phone_Number Paying Customer  \
# 0         1001      Frodo     Baggins  123-545-5421               Y
# 1         1002       Abed       Nadir  123/643/9775               N
# 2         1003     Walter       White    7066950392               N
# 3         1004     Dwight     Schrute  123-543-2345               Y
# 4         1005        Jon        Snow  876|678|3469               Y
# 5         1006        Ron     Swanson  304-762-2467               Y
# 6         1007       Jeff      Winger                             N
# 7         1008   Sherlock      Holmes  876|678|3469               N
# 8         1009    Gandalf         NaN                             Y
# 9         1010      Peter      Parker  123-545-5421               Y
# 10        1011    Samwise      Gamgee                             Y
# 11        1012      Harry      Potter    7066950392               Y
# 12        1013        Don      Draper  123-543-2345               Y
# ...

# %%
df
# Out:
#     CustomerID First_Name   Last_Name  Phone_Number Paying Customer  \
# 0         1001      Frodo     Baggins  123-545-5421               Y
# 1         1002       Abed       Nadir  123/643/9775               N
# 2         1003     Walter       White    7066950392               N
# 3         1004     Dwight     Schrute  123-543-2345               Y
# 4         1005        Jon        Snow  876|678|3469               Y
# 5         1006        Ron     Swanson  304-762-2467               Y
# 6         1007       Jeff      Winger                             N
# 7         1008   Sherlock      Holmes  876|678|3469               N
# 8         1009    Gandalf         NaN                             Y
# 9         1010      Peter      Parker  123-545-5421               Y
# 10        1011    Samwise      Gamgee                             Y
# 11        1012      Harry      Potter    7066950392               Y
# 12        1013        Don      Draper  123-543-2345               Y
# ...

# %%
df.fillna('')
# Out:
#     CustomerID First_Name   Last_Name  Phone_Number Paying Customer  \
# 0         1001      Frodo     Baggins  123-545-5421               Y
# 1         1002       Abed       Nadir  123/643/9775               N
# 2         1003     Walter       White    7066950392               N
# 3         1004     Dwight     Schrute  123-543-2345               Y
# 4         1005        Jon        Snow  876|678|3469               Y
# 5         1006        Ron     Swanson  304-762-2467               Y
# 6         1007       Jeff      Winger                             N
# 7         1008   Sherlock      Holmes  876|678|3469               N
# 8         1009    Gandalf                                         Y
# 9         1010      Peter      Parker  123-545-5421               Y
# 10        1011    Samwise      Gamgee                             Y
# 11        1012      Harry      Potter    7066950392               Y
# 12        1013        Don      Draper  123-543-2345               Y
# ...

# %%
for x in df.index:
    if df.loc[x, 'Do_Not_Contact'] == 'N':
        df.drop(x, inplace=True)
df.head()
df = df.dropna(subset='Phone_Number')
df.head()
# Out:
#    CustomerID First_Name Last_Name  Phone_Number Paying Customer  \
# 1        1002       Abed     Nadir  123/643/9775               N
# 2        1003     Walter     White    7066950392               N
# 3        1004     Dwight   Schrute  123-543-2345               Y
# 5        1006        Ron   Swanson  304-762-2467               Y
# 8        1009    Gandalf       NaN                             Y
#
#   Do_Not_Contact  Not_Useful_Column               Street          State  \
# 1              Y              False  93 West Main Street           None
# 2            NaN               True   298 Drugs Driveway           None
# 3              Y               True     980 Paper Avenue   Pennsylvania
# 5              Y               True     768 City Parkway           None
# 8            NaN              False     123 Middle Earth           None
#
#   Zip_code
# 1     None
# 2     None
# 3    18503
# 5     None
# 8     None

# %%
df.reset_index(drop=True)
# Out:
#    CustomerID First_Name Last_Name  Phone_Number Paying Customer  \
# 0        1002       Abed     Nadir  123/643/9775               N
# 1        1003     Walter     White    7066950392               N
# 2        1004     Dwight   Schrute  123-543-2345               Y
# 3        1006        Ron   Swanson  304-762-2467               Y
# 4        1009    Gandalf       NaN                             Y
# 5        1012      Harry    Potter    7066950392               Y
# 6        1018      Clark      Kent    7066950392               Y
# 7        1019      Creed    Braton                           N/a
#
#   Do_Not_Contact  Not_Useful_Column                Street          State  \
# 0              Y              False   93 West Main Street           None
# 1            NaN               True    298 Drugs Driveway           None
# 2              Y               True      980 Paper Avenue   Pennsylvania
# 3              Y               True      768 City Parkway           None
# ...
